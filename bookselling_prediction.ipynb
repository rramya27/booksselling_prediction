# %%
import pandas
df=pandas.read_csv("books.csv")
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0                               A Light in the Attic
# 1             1                                 Tipping the Velvet
# 2             2                                         Soumission
# 3             3                                      Sharp Objects
# 4             4              Sapiens: A Brief History of Humankind
# ..          ...                                                ...
# 995         995  Alice in Wonderland (Alice's Adventures in Won...
# 996         996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# 997         997  A Spy's Devotion (The Regency Spies of London #1)
# 998         998                1st to Die (Women's Murder Club #1)
# 999         999                 1,000 Places to See Before You Die
#
#                Category  Price  Price_After_Tax  Tax_amount  Avilability  \
# 0                Poetry  51.77            51.77           0           22
# ...

# %%
#display first 2 head,2 colums
df.head(2)
(df.tail(5))
# Out:
#      Unnamed: 0                                              Title  \
# 995         995  Alice in Wonderland (Alice's Adventures in Won...
# 996         996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# 997         997  A Spy's Devotion (The Regency Spies of London #1)
# 998         998                1st to Die (Women's Murder Club #1)
# 999         999                 1,000 Places to See Before You Die
#
#                Category  Price  Price_After_Tax  Tax_amount  Avilability  \
# 995            Classics  55.53            55.53           0            1
# 996      Sequential Art  57.06            57.06           0            1
# 997  Historical Fiction  16.97            16.97           0            1
# 998             Mystery  53.98            53.98           0            1
# 999              Travel  26.08            26.08           0            1
#
#      Number_of_reviews                                   Book_Description  \
# ...

# %%
#display first 5 rows
df.head()
# Out:
#    Unnamed: 0                                  Title            Category  \
# 0           0                   A Light in the Attic              Poetry
# 1           1                     Tipping the Velvet  Historical Fiction
# 2           2                             Soumission             Fiction
# 3           3                          Sharp Objects             Mystery
# 4           4  Sapiens: A Brief History of Humankind             History
#
#    Price  Price_After_Tax  Tax_amount  Avilability  Number_of_reviews  \
# 0  51.77            51.77           0           22                  0
# 1  53.74            53.74           0           20                  0
# 2  50.10            50.10           0           20                  0
# 3  47.82            47.82           0           20                  0
# 4  54.23            54.23           0           20                  0
#
#                                     Book_Description  \
# ...

# %%
print(df.shape)
# Out:
# (1000, 11)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1000 non-null   int64
#  1   Title              1000 non-null   object
#  2   Category           1000 non-null   object
#  3   Price              1000 non-null   float64
#  4   Price_After_Tax    1000 non-null   float64
#  5   Tax_amount         1000 non-null   int64
#  6   Avilability        1000 non-null   int64
#  7   Number_of_reviews  1000 non-null   int64
#  8   Book_Description   1000 non-null   object
#  9   Image_Link         1000 non-null   object
#  10  Stars              1000 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 86.1+ KB
# None

# %%
print(df.describe())
# Out:
#         Unnamed: 0       Price  Price_After_Tax  Tax_amount  Avilability  \
# count  1000.000000  1000.00000       1000.00000      1000.0  1000.000000
# mean    499.500000    35.07035         35.07035         0.0     8.585000
# std     288.819436    14.44669         14.44669         0.0     5.654622
# min       0.000000    10.00000         10.00000         0.0     1.000000
# 25%     249.750000    22.10750         22.10750         0.0     3.000000
# 50%     499.500000    35.98000         35.98000         0.0     7.000000
# 75%     749.250000    47.45750         47.45750         0.0    14.000000
# max     999.000000    59.99000         59.99000         0.0    22.000000
#
#        Number_of_reviews        Stars
# count             1000.0  1000.000000
# mean                 0.0     2.923000
# std                  0.0     1.434967
# min                  0.0     1.000000
# 25%                  0.0     2.000000
# 50%                  0.0     3.000000
# 75%                  0.0     4.000000
# ...

# %%
print(df.isnull())
# Out:
#      Unnamed: 0  Title  Category  Price  Price_After_Tax  Tax_amount  \
# 0         False  False     False  False            False       False
# 1         False  False     False  False            False       False
# 2         False  False     False  False            False       False
# 3         False  False     False  False            False       False
# 4         False  False     False  False            False       False
# ..          ...    ...       ...    ...              ...         ...
# 995       False  False     False  False            False       False
# 996       False  False     False  False            False       False
# 997       False  False     False  False            False       False
# 998       False  False     False  False            False       False
# 999       False  False     False  False            False       False
#
#      Avilability  Number_of_reviews  Book_Description  Image_Link  Stars
# ...

# %%
print(df.isnull().any())
# Out:
# Unnamed: 0           False
# Title                False
# Category             False
# Price                False
# Price_After_Tax      False
# Tax_amount           False
# Avilability          False
# Number_of_reviews    False
# Book_Description     False
# Image_Link           False
# Stars                False
# dtype: bool

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0           0
# Title                0
# Category             0
# Price                0
# Price_After_Tax      0
# Tax_amount           0
# Avilability          0
# Number_of_reviews    0
# Book_Description     0
# Image_Link           0
# Stars                0
# dtype: int64

# %%
#delete row
df.drop(1,inplace=True)
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0                               A Light in the Attic
# 2             2                                         Soumission
# 3             3                                      Sharp Objects
# 4             4              Sapiens: A Brief History of Humankind
# 5             5                                    The Requiem Red
# ..          ...                                                ...
# 995         995  Alice in Wonderland (Alice's Adventures in Won...
# 996         996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# 997         997  A Spy's Devotion (The Regency Spies of London #1)
# 998         998                1st to Die (Women's Murder Club #1)
# 999         999                 1,000 Places to See Before You Die
#
#                Category  Price  Price_After_Tax  Tax_amount  Avilability  \
# 0                Poetry  51.77            51.77           0           22
# ...

# %%
df.drop(columns=["Number_of_reviews"],inplace=True)
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0                               A Light in the Attic
# 1             1                                 Tipping the Velvet
# 2             2                                         Soumission
# 3             3                                      Sharp Objects
# 4             4              Sapiens: A Brief History of Humankind
# ..          ...                                                ...
# 995         995  Alice in Wonderland (Alice's Adventures in Won...
# 996         996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# 997         997  A Spy's Devotion (The Regency Spies of London #1)
# 998         998                1st to Die (Women's Murder Club #1)
# 999         999                 1,000 Places to See Before You Die
#
#                Category  Price  Price_After_Tax  Tax_amount  Avilability  \
# 0                Poetry  51.77            51.77           0           22
# ...

# %%
#finding mean value for columns
print(df["Price"].mean())
# Out:
# 35.07035

# %%
#finding median value for the columns
print(df["Price"].median())
# Out:
# 35.980000000000004

# %%
# Book with Maximum 'Price'

df[df['Price'] == df['Price'].max()]
# Out:
#      Unnamed: 0                               Title Category  Price  \
# 648         648  The Perfect Play (Play by Play #1)  Romance  59.99
#
#      Price_After_Tax  Tax_amount  Avilability  \
# 648            59.99           0            4
#
#                                       Book_Description  \
# 648  Football pro Mick Riley is an all-star, both o...
#
#                                             Image_Link  Stars
# 648  http://books.toscrape.com/media/cache/b0/be/b0...      3

# %%
# Book with Minimum 'Price'

df[df['Price'] == df['Price'].min()]
# Out:
#      Unnamed: 0                       Title     Category  Price  \
# 638         638  An Abundance of Katherines  Young Adult   10.0
#
#      Price_After_Tax  Tax_amount  Avilability  \
# 638             10.0           0            5
#
#                                       Book_Description  \
# 638  Katherine V thought boys were gross Katherine ...
#
#                                             Image_Link  Stars
# 638  http://books.toscrape.com/media/cache/9b/c8/9b...      5

# %%
#finding the maximum stars
df[df['Stars'] == df['Stars'].max()]
# Out:
#      Unnamed: 0                                              Title  \
# 4             4              Sapiens: A Brief History of Humankind
# 12           12                                        Set Me Free
# 13           13  Scott Pilgrim's Precious Little Life (Scott Pi...
# 14           14                          Rip it Up and Start Again
# 23           23                         Chase Me (Paris Nights #2)
# ..          ...                                                ...
# 985         985                    Deep Under (Walker Security #1)
# 989         989                                       Bright Lines
# 993         993  Bleach, Vol. 1: Strawberry and the Soul Reaper...
# 997         997  A Spy's Devotion (The Regency Spies of London #1)
# 999         999                 1,000 Places to See Before You Die
#
#                Category  Price  Price_After_Tax  Tax_amount  Avilability  \
# 4               History  54.23            54.23           0           20
# ...

# %%
#finding the minimum stars
df[df['Stars'] == df['Stars'].min()]
# Out:
#      Unnamed: 0                                              Title  \
# 1             1                                 Tipping the Velvet
# 2             2                                         Soumission
# 5             5                                    The Requiem Red
# 9             9                                    The Black Maria
# 16           16                                               Olio
# ..          ...                                                ...
# 988         988          Charity's Cross (Charles Towne Belles #4)
# 990         990           Bridget Jones's Diary (Bridget Jones #1)
# 994         994                               Beyond Good and Evil
# 995         995  Alice in Wonderland (Alice's Adventures in Won...
# 998         998                1st to Die (Women's Murder Club #1)
#
#                Category  Price  Price_After_Tax  Tax_amount  Avilability  \
# 1    Historical Fiction  53.74            53.74           0           20
# ...

# %%
df.groupby(['Title']).max().sort_values(by='Avilability', ascending=False)['Avilability']
# Out:
# Title
# A Light in the Attic                                        22
# Soumission                                                  20
# Tipping the Velvet                                          20
# Sharp Objects                                               20
# Sapiens: A Brief History of Humankind                       20
#                                                             ..
# Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)            1
# Having the Barbarian's Baby (Ice Planet Barbarians #7.5)     1
# The Art of Not Breathing                                     1
# The Silent Wife                                              1
# Bounty (Colorado Mountain #7)                                1
# Name: Avilability, Length: 999, dtype: int64

# %%
import matplotlib.pyplot as mp

# %%
#barplot for only first ten price
df.head(10).plot.bar(x="Price",y="Price_After_Tax")
# Out:
# <AxesSubplot: xlabel='Price'>

# %%
#bar plt for entiry data set
df.plot.bar(x="Price",y="Price_After_Tax")
# Out:
# <AxesSubplot: xlabel='Price'>

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %%
df.plot(kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
import seaborn

# %%
#correlation
cor=df.corr()
seaborn.heatmap(cor,annot=True)
# Out:
# C:\Users\RAMYA\AppData\Local\Temp\ipykernel_12696\3640347540.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()
# <AxesSubplot: >
